# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# sns.set_style()

# %%
comp = pd.read_csv("../data/comp.csv")

# %%
comp.phylum.value_counts().head(10)
# Out:
# Proteobacteria       398
# Firmicutes           214
# Actinobacteriota     113
# Bacteroidota         107
# Desulfobacterota      76
# Chloroflexi           67
# Verrucomicrobiota     61
# Planctomycetota       57
# Acidobacteriota       37
# Patescibacteria       35
# Name: phylum, dtype: int64

# %% [markdown]
# ## Composition Stackplot

# %%
comp
# Out:
#       2cm Gotland  20cm Gotland  40cm Gotland  80cm Gotland  120cm Gotland  \
# 0        10.46120        1.1149       1.00465       0.54855        0.29410
# 1         3.50275        0.4323       0.23410       0.23175        0.11385
# 2         4.32900       15.8703      12.43845      16.66055        1.42445
# 3         3.19500        2.7759       1.50360       2.15655        0.79220
# 4         2.78275        1.7747       3.42070       0.80630        0.64980
# ...           ...           ...           ...           ...            ...
# 1401      0.00000        0.0114       0.00000       0.00000        0.00000
# 1402      0.00560        0.0000       0.00000       0.00000        0.00000
# 1403      0.00560        0.0000       0.00000       0.00000        0.00000
# 1404      0.00000        0.0000       0.00000       0.00000        0.01850
# 1405      0.00000        0.0114       0.02730       0.02670        0.00665
#
#       145cm Gotland  185cm Gotland  220cm Gotland  270cm Gotland   2cm Fin  \
# 0           0.91300        1.27650        0.89165         1.10160  2.25905
# 1           0.23995        0.38340        0.37140         0.16495  0.37970
# 2           2.88385        2.40605       16.13270         5.03310  3.04790
# 3           0.38665        0.31675        2.93155         0.42755  0.47560
# 4           1.71630        3.14345        1.94490         2.89585  1.75310
# ...             ...            ...            ...             ...      ...
# 1401        0.00920        0.00000        0.00000         0.00000  0.00000
# 1402        0.00000        0.00000        0.00000         0.00000  0.00000
# 1403        0.00000        0.00000        0.00000         0.00000  0.00000
# 1404        0.00920        0.00790        0.01360         0.00000  0.01260
# 1405        0.00920        0.00000        0.01910         0.01610  0.00000
#
#       ...  80cm Fin  110cm Fin   150cm Fin  190cm Fin    domain  \
# 0     ...   2.56830     4.62990    2.93200   14.38855  Bacteria
# 1     ...   0.67300     0.43200    0.25725    1.48010  Bacteria
# 2     ...   4.69460     3.30370    2.81250    2.87730  Bacteria
# 3     ...   0.69750     0.72555    0.59005    1.31790  Bacteria
# 4     ...   5.83765     1.85370    4.98280    4.42205  Bacteria
# ...   ...       ...         ...        ...        ...       ...
# 1401  ...   0.00000     0.00000    0.00000    0.00000  Bacteria
# 1402  ...   0.00000     0.00000    0.00000    0.00000  Bacteria
# 1403  ...   0.00000     0.00000    0.00000    0.00000  Bacteria
# 1404  ...   0.00000     0.00750    0.00625    0.00000  Bacteria
# 1405  ...   0.01855     0.00000    0.00000    0.01505  Bacteria
#
#                  phylum             class                order  \
# 0      Actinobacteriota    Actinobacteria    Corynebacteriales
# 1      Actinobacteriota   Thermoleophilia  Solirubrobacterales
# 2           Chloroflexi      Anaerolineae       Anaerolineales
# 3      Desulfobacterota   Desulfobacteria    Desulfobacterales
# 4      Actinobacteriota   Thermoleophilia  Solirubrobacterales
# ...                 ...               ...                  ...
# 1401  Verrucomicrobiota  Verrucomicrobiae  S-BQ2-57 soil group
# 1402  Verrucomicrobiota  Verrucomicrobiae   Verrucomicrobiales
# 1403  Verrucomicrobiota  Verrucomicrobiae   Verrucomicrobiales
# 1404                WS4               NaN                  NaN
# 1405         uncultured               NaN                  NaN
#
#                     family           genus
# 0         Mycobacteriaceae   Mycobacterium
# 1     Solirubrobacteraceae    Conexibacter
# 2          Anaerolineaceae      uncultured
# 3       Desulfosarcinaceae       SEEP-SRB1
# 4                    67-14             NaN
# ...                    ...             ...
# 1401                   NaN             NaN
# 1402        Rubritaleaceae  Persicirhabdus
# 1403   Verrucomicrobiaceae      uncultured
# 1404                   NaN             NaN
# 1405                   NaN             NaN
#
# [1406 rows x 23 columns]

# %%
comp.iloc[:, :17].sum(axis=0)
# Out:
# 2cm Gotland        99.90525
# 20cm Gotland      100.00530
# 40cm Gotland       99.99410
# 80cm Gotland      100.00185
# 120cm Gotland     100.00095
# 145cm Gotland      99.99970
# 185cm Gotland     100.00000
# 220cm Gotland      99.99515
# 270cm Gotland     100.00040
# 2cm Fin            99.99855
# 10cm Fin           99.99455
# 20cm Fin          100.00105
# 40cm Fin           99.99645
# 80cm Fin           99.99795
# 110cm Fin         100.00140
# 150cm Fin         100.00235
# 190cm Fin         100.00250
# dtype: float64

# %%
comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1406 entries, 0 to 1405
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   2cm Gotland     1405 non-null   float64
#  1   20cm Gotland    1406 non-null   float64
#  2   40cm Gotland    1406 non-null   float64
#  3   80cm Gotland    1406 non-null   float64
#  4   120cm Gotland   1406 non-null   float64
#  5   145cm Gotland   1406 non-null   float64
#  6   185cm Gotland   1406 non-null   float64
#  7   220cm Gotland   1406 non-null   float64
#  8   270cm Gotland   1406 non-null   float64
#  9   2cm Fin         1406 non-null   float64
#  10  10cm Fin        1406 non-null   float64
#  11  20cm Fin        1406 non-null   float64
#  12  40cm Fin        1406 non-null   float64
#  13  80cm Fin        1406 non-null   float64
#  14  110cm Fin       1406 non-null   float64
#  15  150cm Fin       1406 non-null   float64
#  16  190cm Fin       1406 non-null   float64
#  17  domain          1406 non-null   object
#  18  phylum          1405 non-null   object
#  19  class           1373 non-null   object
#  20  order           1305 non-null   object
#  21  family          1123 non-null   object
#  22  genus           929 non-null    object
# dtypes: float64(17), object(6)
# memory usage: 252.8+ KB

# %%
def get_full_taxa(ser):
    levels = ["phylum","class", "order", "family", "genus"]
    full_taxa = ""
    for l in levels:
        t = ser[l]
        if isinstance(t, str):
            full_taxa += t + "__"
    full_taxa = full_taxa.strip("__")
    return full_taxa

comp["FullTaxa"] = comp.apply(get_full_taxa, axis=1)

# %%
comp_melted = comp.melt(id_vars=["phylum", "family", "FullTaxa"], value_vars=comp.columns[:17], var_name="sample_name", value_name="share") # id_vars=comp.columns[17:]
comp_melted["family"] = comp_melted["family"].fillna("unknown")
comp_melted = comp_melted.groupby(["sample_name", "FullTaxa", "phylum", "family"]).share.sum().reset_index()
comp_melted["sample_name"] = comp_melted["sample_name"].str.strip()
comp_melted["Column"] = comp_melted.sample_name.apply(lambda x: x.split()[-1])
comp_melted["Depth"] = comp_melted.sample_name.str.extract("(\d{1,3})cm\s.+").astype(np.int16)

# comp_melted.dropna(inplace=True)  # TODO is it optimal step??
comp_melted
# Out:
#         sample_name                                           FullTaxa  \
# 0          10cm Fin                                           10bav-F6
# 1          10cm Fin  Abditibacteriota__Abditibacteria__Abditibacter...
# 2          10cm Fin                        Acetothermia__Acetothermiia
# 3          10cm Fin                          Acidobacteriota__AT-s3-28
# 4          10cm Fin           Acidobacteriota__Acidobacteriae__AKIW659
# ...             ...                                                ...
# 23880  80cm Gotland                                                WS1
# 23881  80cm Gotland                                                WS2
# 23882  80cm Gotland                                                WS4
# 23883  80cm Gotland                                       Zixibacteria
# 23884  80cm Gotland                                         uncultured
#
#                  phylum              family    share   Column  Depth
# 0              10bav-F6             unknown  0.02385      Fin     10
# 1      Abditibacteriota  Abditibacteriaceae  0.00960      Fin     10
# 2          Acetothermia             unknown  0.06695      Fin     10
# 3       Acidobacteriota             unknown  0.01925      Fin     10
# 4       Acidobacteriota             unknown  0.00000      Fin     10
# ...                 ...                 ...      ...      ...    ...
# 23880               WS1             unknown  0.14485  Gotland     80
# 23881               WS2             unknown  0.09680  Gotland     80
# 23882               WS4             unknown  0.00000  Gotland     80
# 23883      Zixibacteria             unknown  0.75825  Gotland     80
# 23884        uncultured             unknown  0.02670  Gotland     80
#
# [23885 rows x 7 columns]

# %%
comp_melted.groupby("sample_name").share.sum()
# Out:
# sample_name
# 10cm Fin         97.35895
# 110cm Fin        98.44700
# 120cm Gotland    97.35615
# 145cm Gotland    97.10600
# 150cm Fin        99.50980
# 185cm Gotland    98.35265
# 190cm Fin        99.12045
# 20cm Fin         98.48265
# 20cm Gotland     97.22940
# 220cm Gotland    98.10930
# 270cm Gotland    98.73990
# 2cm Fin          99.62490
# 2cm Gotland      97.32410
# 40cm Fin         95.90205
# 40cm Gotland     97.55880
# 80cm Fin         99.04280
# 80cm Gotland     96.66485
# Name: share, dtype: float64

# %%
one_cm = comp_melted[(comp_melted.phylum == "Chloroflexi") & (comp_melted.Column == "Gotland")]
one_cm
# Out:
#          sample_name                                           FullTaxa  \
# 3111   120cm Gotland                          Chloroflexi__Anaerolineae
# 3112   120cm Gotland            Chloroflexi__Anaerolineae__ADurb.Bin180
# 3113   120cm Gotland  Chloroflexi__Anaerolineae__Anaerolineales__Ana...
# 3114   120cm Gotland  Chloroflexi__Anaerolineae__Anaerolineales__Ana...
# 3115   120cm Gotland  Chloroflexi__Anaerolineae__Anaerolineales__Ana...
# ...              ...                                                ...
# 22843   80cm Gotland  Chloroflexi__Ktedonobacteria__Ktedonobacterale...
# 22844   80cm Gotland  Chloroflexi__Ktedonobacteria__Ktedonobacterale...
# 22845   80cm Gotland  Chloroflexi__Ktedonobacteria__Ktedonobacterale...
# 22846   80cm Gotland                                 Chloroflexi__OLB14
# 22847   80cm Gotland                                  Chloroflexi__TK10
#
#             phylum              family    share   Column  Depth
# 3111   Chloroflexi             unknown  0.00000  Gotland    120
# 3112   Chloroflexi             unknown  0.12190  Gotland    120
# 3113   Chloroflexi     Anaerolineaceae  0.00000  Gotland    120
# 3114   Chloroflexi     Anaerolineaceae  0.00665  Gotland    120
# 3115   Chloroflexi     Anaerolineaceae  0.01850  Gotland    120
# ...            ...                 ...      ...      ...    ...
# 22843  Chloroflexi  Ktedonobacteraceae  0.00000  Gotland     80
# 22844  Chloroflexi  Ktedonobacteraceae  0.00000  Gotland     80
# 22845  Chloroflexi  Ktedonobacteraceae  0.00000  Gotland     80
# 22846  Chloroflexi             unknown  0.00000  Gotland     80
# 22847  Chloroflexi             unknown  0.00000  Gotland     80
#
# [603 rows x 7 columns]

# %%
one_cm.groupby("sample_name").share.sum()
# Out:
# sample_name
# 120cm Gotland     8.76750
# 145cm Gotland     9.55335
# 185cm Gotland    10.68455
# 20cm Gotland     24.51700
# 220cm Gotland    24.79110
# 270cm Gotland    19.52425
# 2cm Gotland       9.27405
# 40cm Gotland     19.81155
# 80cm Gotland     25.61910
# Name: share, dtype: float64

# %%
cutoff = 1
stacked = one_cm.pivot(index="Depth", columns="FullTaxa", values="share")
stacked = stacked.loc[:, (stacked.sum(axis=0) > cutoff)]
stacked = stacked.iloc[:, stacked.sum(axis=0).values.argsort()]
print(stacked.shape)
stacked
# Out:
# (9, 19)
# FullTaxa  Chloroflexi__Anaerolineae__Caldilineales__Caldilineaceae__uncultured  \
# Depth
# 2                                                   0.20250
# 20                                                  0.28440
# 40                                                  0.15080
# 80                                                  0.17155
# 120                                                 0.03840
# 145                                                 0.00000
# 185                                                 0.00000
# 220                                                 0.14890
# 270                                                 0.00945
#
# FullTaxa  Chloroflexi__Anaerolineae__Anaerolineales__Anaerolineaceae__Ornatilinea  \
# Depth
# 2                                                   0.44815
# 20                                                  0.18200
# 40                                                  0.08960
# 80                                                  0.12385
# 120                                                 0.00665
# 145                                                 0.00000
# 185                                                 0.02795
# 220                                                 0.14615
# 270                                                 0.00000
#
# FullTaxa  Chloroflexi__Dehalococcoidia__FW22  \
# Depth
# 2                                    0.00560
# 20                                   0.04550
# 40                                   0.05500
# 80                                   0.21005
# 120                                  0.14845
# 145                                  0.09695
# 185                                  0.28380
# 220                                  0.11170
# 270                                  0.39250
#
# FullTaxa  Chloroflexi__Dehalococcoidia__S085  \
# Depth
# 2                                    0.02230
# 20                                   0.05690
# 40                                   0.09635
# 80                                   0.01070
# 120                                  0.00000
# 145                                  0.05275
# 185                                  0.13965
# 220                                  0.03995
# 270                                  1.02000
#
# FullTaxa  Chloroflexi__Dehalococcoidia__Napoli-4B-65  \
# Depth
# 2                                            0.00000
# 20                                           0.05690
# 40                                           0.07540
# 80                                           0.10750
# 120                                          0.14040
# 145                                          0.05340
# 185                                          0.54255
# 220                                          0.06810
# 270                                          0.40965
#
# FullTaxa  Chloroflexi__Dehalococcoidia__vadinBA26  \
# Depth
# 2                                         0.00560
# 20                                        0.07960
# 40                                        0.11675
# 80                                        0.19940
# 120                                       0.13375
# 145                                       0.12585
# 185                                       0.32150
# 220                                       0.04540
# 270                                       0.48150
#
# FullTaxa  Chloroflexi__Dehalococcoidia__Sh765B-AG-111  \
# Depth
# 2                                             0.00000
# 20                                            0.06830
# 40                                            0.09600
# 80                                            0.12385
# 120                                           0.11525
# 145                                           0.08960
# 185                                           0.60155
# 220                                           0.06900
# 270                                           0.36310
#
# FullTaxa  Chloroflexi__Dehalococcoidia__GIF3  Chloroflexi__Dehalococcoidia  \
# Depth
# 2                                    0.02535                       0.00000
# 20                                   0.06830                       0.14790
# 40                                   0.12390                       0.08905
# 80                                   0.35530                       0.19900
# 120                                  0.21865                       0.37615
# 145                                  0.15095                       0.32955
# 185                                  0.37505                       0.27920
# 220                                  0.08810                       0.05905
# 270                                  0.41810                       0.38660
#
# FullTaxa  Chloroflexi__Dehalococcoidia__GIF9__AB-539-J10__SCGC-AB-539-J10  \
# Depth
# 2                                                   0.00000
# 20                                                  0.04550
# 40                                                  0.00690
# 80                                                  0.00535
# 120                                                 0.09010
# 145                                                 0.05340
# 185                                                 0.93430
# 220                                                 0.00635
# 270                                                 1.25250
#
# FullTaxa  Chloroflexi__Anaerolineae__ADurb.Bin180  \
# Depth
# 2                                         0.08170
# 20                                        0.34130
# 40                                        0.35105
# 80                                        0.41295
# 120                                       0.12190
# 145                                       0.13190
# 185                                       0.57840
# 220                                       0.42315
# 270                                       0.38765
#
# FullTaxa  Chloroflexi__Anaerolineae__Anaerolineales__Anaerolineaceae__Pelolinea  \
# Depth
# 2                                                   0.20250
# 20                                                  0.47780
# 40                                                  0.46835
# 80                                                  0.73085
# 120                                                 0.42125
# 145                                                 0.53635
# 185                                                 0.61055
# 220                                                 0.46930
# 270                                                 0.24165
#
# FullTaxa  Chloroflexi__Anaerolineae__Anaerolineales__Anaerolineaceae__Longilinea  \
# Depth
# 2                                                   0.16845
# 20                                                  0.50060
# 40                                                  0.54260
# 80                                                  0.78925
# 120                                                 0.68640
# 145                                                 1.14680
# 185                                                 0.20190
# 220                                                 0.55925
# 270                                                 0.08440
#
# FullTaxa  Chloroflexi__Anaerolineae__uncultured  \
# Depth
# 2                                       0.57305
# 20                                      1.16040
# 40                                      0.88745
# 80                                      0.71870
# 120                                     0.06355
# 145                                     0.08100
# 185                                     0.13025
# 220                                     1.07850
# 270                                     0.12505
#
# FullTaxa  Chloroflexi__Dehalococcoidia__MSBL5  \
# Depth
# 2                                     0.22480
# 20                                    1.06940
# 40                                    0.46875
# 80                                    1.12385
# 120                                   0.59485
# 145                                   0.49390
# 185                                   0.54720
# 220                                   1.14200
# 270                                   0.87475
#
# FullTaxa  Chloroflexi__Anaerolineae__MSB-5B2  Chloroflexi__KD4-96  \
# Depth
# 2                                    0.01980              0.63230
# 20                                   0.27300              1.41070
# 40                                   0.15810              1.64515
# 80                                   0.10180              0.98360
# 120                                  0.06355              1.44015
# 145                                  0.19325              1.34635
# 185                                  0.19775              0.49180
# 220                                  0.13440              1.60605
# 270                                  5.62960              0.12045
#
# FullTaxa  Chloroflexi__Anaerolineae__SBR1031  \
# Depth
# 2                                    0.91955
# 20                                   1.70650
# 40                                   1.49785
# 80                                   1.96260
# 120                                  1.99475
# 145                                  1.04135
# 185                                  0.53930
# 220                                  1.94760
# 270                                  0.73745
#
# FullTaxa  Chloroflexi__Anaerolineae__Anaerolineales__Anaerolineaceae__uncultured
# Depth
# 2                                                   4.32900
# 20                                                 15.87030
# 40                                                 12.43845
# 80                                                 16.66055
# 120                                                 1.42445
# 145                                                 2.88385
# 185                                                 2.40605
# 220                                                16.13270
# 270                                                 5.03310

# %%
def plot_stacked(comp_melted, phylum, filepath=None, bpos=0.12, show=True, cutoff=.2):
    columns = ['Fin', 'Gotland']

    fig, axs = plt.subplots(1, 2)
    fig.set_size_inches((24, 8))

    max_share = 0
    yticks_max = 0
    both_stacked = []
    for sample in columns:
        one_cm = comp_melted[(comp_melted.phylum == phylum) & (comp_melted.Column == sample)]
        stacked = one_cm.pivot(index="Depth", columns="FullTaxa", values="share")
        stacked = stacked.loc[:, (stacked.mean(axis=0) > cutoff)]
        stacked = stacked.iloc[:, stacked.mean(axis=0).values.argsort()]
        max_share = max(max_share, stacked.sum(axis=1).max())
        yticks_max = max(yticks_max, stacked.index.max())
        # scale to one
        # stacked = (stacked / stacked.sum(axis=1).values.reshape(-1, 1))
        both_stacked.append(stacked)
    
    # add missing common phylums and sort identically both stacked tables
    for c in set(both_stacked[0].columns) - set(both_stacked[1].columns):
        both_stacked[1][c] = 0.0
    for c in set(both_stacked[1].columns) - set(both_stacked[0].columns):
        both_stacked[0][c] = 0.0
    _order = both_stacked[0].mean(axis=0).values.argsort()
    order = both_stacked[0].columns[_order]

    # plot
    for im, stacked in enumerate(both_stacked):
        stacked = stacked[order]
        data = np.cumsum(stacked.values, axis=1)
        for i, col in enumerate(stacked.columns):
            axs[im].fill_betweenx(stacked.index, data[:,i], label=col, zorder=-i)  # TODO add coloring here using dict[i, color] like dict[i, label(col)]
        axs[im].margins(y=0)
        axs[im].set_xlim(0, max_share + .5)
        axs[im].set_axisbelow(False)
        axs[im].set_ylabel("Глубина, см", fontsize=14)
        axs[im].set_xlabel("Доля таксона в образце, %", fontsize=14)
        axs[im].set_title(columns[im], fontsize=16)
        axs[im].grid(False)

        # Shrink current axis's height by 10% on the bottom
        box = axs[im].get_position()
        new_box = [
            box.x0, box.y0 + box.height * 0.1,
            box.width, box.height * 0.9
        ]
        axs[im].set_position(new_box)
        
        yticks = stacked.index.values
        if yticks.max() < yticks_max:
            yticks = list(stacked.index.values) + [yticks_max]
        axs[im].set_yticks(yticks)

        # Put a legend below current axis
        if im == 0:
            axs[im].legend(loc='upper center', bbox_to_anchor=(1.08, -bpos), ncol=1, fontsize=14)

    if filepath is not None:
        plt.savefig(filepath, bbox_inches='tight')
    if show:
        plt.show()
    else:
        plt.close(fig)


plot_stacked(comp_melted, "Planctomycetota")

# %%
def plot_stacked_shit(comp_melted, phylum, outdir=None, bpos=0.18, show=True, cutoff=.2):
    columns = ['Fin', 'Gotland']
    max_share = 0
    yticks_max = 0
    both_stacked = []
    for sample in columns:
        one_cm = comp_melted[(comp_melted.phylum == phylum) & (comp_melted.Column == sample)]
        stacked = one_cm.pivot(index="Depth", columns="FullTaxa", values="share")
        stacked = stacked.loc[:, (stacked.mean(axis=0) > cutoff)]
        stacked = stacked.iloc[:, stacked.mean(axis=0).values.argsort()]
        max_share = max(max_share, stacked.sum(axis=1).max())
        yticks_max = max(yticks_max, stacked.index.max())
        # scale to one
        # stacked = (stacked / stacked.sum(axis=1).values.reshape(-1, 1))
        both_stacked.append(stacked)
    
    # add missing common phylums and sort identically both stacked tables
    for c in set(both_stacked[0].columns) - set(both_stacked[1].columns):
        both_stacked[1][c] = 0.0
    for c in set(both_stacked[1].columns) - set(both_stacked[0].columns):
        both_stacked[0][c] = 0.0
    _order = both_stacked[0].mean(axis=0).values.argsort()
    order = both_stacked[0].columns[_order]

    # plot
    for im, stacked in enumerate(both_stacked):
        fig, ax = plt.subplots()
        if im == 1:
            fig.set_size_inches((12, 8))
        else:
            fig.set_size_inches((12, 6))
        
        stacked = stacked[order]
        data = np.cumsum(stacked.values, axis=1)
        for i, col in enumerate(stacked.columns):
            ax.fill_betweenx(stacked.index, data[:,i], label=col, zorder=-i)  # TODO add coloring here using dict[i, color] like dict[i, label(col)]
        ax.margins(y=0)
        ax.set_xlim(0, max_share + .5)
        ax.set_axisbelow(False)
        ax.set_ylabel("Глубина, см", fontsize=14)
        ax.set_xlabel("Доля таксона в образце, %", fontsize=14)
        ax.set_title(columns[im], fontsize=16)
        ax.grid(False)

        # Shrink current axis's height by 10% on the bottom
        box = ax.get_position()
        new_box = [
            box.x0, box.y0 + box.height * 0.1,
            box.width, box.height * 0.9
        ]
        ax.set_position(new_box)
        ax.set_yticks(stacked.index.values)

        # Put a legend below current axis
        ax.legend(loc='upper center', bbox_to_anchor=(.5, -bpos), ncol=1, fontsize=14)

        if outdir is not None:
            filepath = os.path.join(outdir, f"{ph}_{columns[im]}.png")
            plt.savefig(filepath, bbox_inches='tight')
        if show:
            plt.show()
        else:
            plt.close(fig)


plot_stacked_shit(comp_melted, "Planctomycetota")

# %%
phylums = ["Actinobacteriota", "Chloroflexi", "Desulfobacterota", "Planctomycetota", "Proteobacteria"]
for ph in phylums:     
    plot_stacked_shit(comp_melted, ph, "../figures", show=False)
